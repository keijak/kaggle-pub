# %%
import json
import os
import pickle

import numpy as np
import pandas as pd
import lightgbm as lgb

# %%
df_train_full = pd.read_pickle('train_parsed_nojson.pickle')
df_test_full = pd.read_pickle('test_parsed_nojson.pickle')

# %%
visitor_set = set(df_test_full.fullVisitorId)

# %%
for v in visitor_set:
    print(v)
    print(type(v))
    break
# Out:
# 6454274553732454521
# <class 'str'>

# %%
len(visitor_set)
# Out:
# 296530

# %%
visitor_list = list(visitor_set)
visitor_list.sort()
visitor_list[:10]
# Out:
# ['0000018966949534117',
#  '0000039738481224681',
#  '0000073585230191399',
#  '0000087588448856385',
#  '0000149787903119437',
#  '0000196310838896290',
#  '00001995526696366',
#  '0000255704530917106',
#  '0000268499301061358',
#  '0000276747989270229']

# %%
df_has_revenue = df_test_full.totals_transactionRevenue.astype(np.float64).fillna(0.0) > 0.01

# %%
len(df_has_revenue.astype(np.int32))
# Out:
# 401589

# %%
df_test_full = df_test_full.assign(has_revenue=df_has_revenue.astype(np.int32))

# %%
df_test_full.head().T
# Out:
#                                                                                0  \
# channelGrouping                                                   Organic Search
# date                                                                    20180511
# fullVisitorId                                                7460955084541987166
# socialEngagementType                                        Not Socially Engaged
# visitId                                                               1526099341
# visitNumber                                                                    2
# visitStartTime                                                        1526099341
# rowId                                                                          0
# device_browser                                                            Chrome
# device_browserVersion                              not available in demo dataset
# device_browserSize                                 not available in demo dataset
# device_operatingSystem                                                   Android
# device_operatingSystemVersion                      not available in demo dataset
# device_isMobile                                                             True
# device_mobileDeviceBranding                        not available in demo dataset
# device_mobileDeviceModel                           not available in demo dataset
# device_mobileInputSelector                         not available in demo dataset
# device_mobileDeviceInfo                            not available in demo dataset
# device_mobileDeviceMarketingName                   not available in demo dataset
# device_flashVersion                                not available in demo dataset
# device_language                                    not available in demo dataset
# device_screenColors                                not available in demo dataset
# device_screenResolution                            not available in demo dataset
# device_deviceCategory                                                     mobile
# geoNetwork_continent                                                        Asia
# geoNetwork_subContinent                                            Southern Asia
# geoNetwork_country                                                         India
# geoNetwork_region                                                          Delhi
# geoNetwork_metro                                                       (not set)
# geoNetwork_city                                                        (not set)
# geoNetwork_cityId                                  not available in demo dataset
# geoNetwork_networkDomain                                         unknown.unknown
# geoNetwork_latitude                                not available in demo dataset
# geoNetwork_longitude                               not available in demo dataset
# geoNetwork_networkLocation                         not available in demo dataset
# totals_bounces                                                               NaN
# totals_hits                                                                    4
# totals_newVisits                                                             NaN
# totals_pageviews                                                               3
# totals_sessionQualityDim                                                       1
# totals_timeOnSite                                                            973
# totals_totalTransactionRevenue                                               NaN
# totals_transactionRevenue                                                    NaN
# totals_transactions                                                          NaN
# totals_visits                                                                  1
# trafficSource_adContent                                                (not set)
# trafficSource_adwordsClickInfo_adNetworkType                                 NaN
# trafficSource_adwordsClickInfo_criteriaParameters  not available in demo dataset
# trafficSource_adwordsClickInfo_gclId                                         NaN
# trafficSource_adwordsClickInfo_isVideoAd                                     NaN
# trafficSource_adwordsClickInfo_page                                          NaN
# trafficSource_adwordsClickInfo_slot                                          NaN
# trafficSource_campaign                                                 (not set)
# trafficSource_isTrueDirect                                                  True
# trafficSource_keyword                                             (not provided)
# trafficSource_medium                                                     organic
# trafficSource_referralPath                                             (not set)
# trafficSource_source                                                      google
# has_revenue                                                                    0
#
#                                                                                    1  \
# channelGrouping                                                               Direct
# date                                                                        20180511
# fullVisitorId                                                     460252456180441002
# socialEngagementType                                            Not Socially Engaged
# visitId                                                                   1526064483
# visitNumber                                                                      166
# visitStartTime                                                            1526064483
# rowId                                                                              1
# device_browser                                                                Chrome
# device_browserVersion                                  not available in demo dataset
# device_browserSize                                     not available in demo dataset
# device_operatingSystem                                                     Macintosh
# device_operatingSystemVersion                          not available in demo dataset
# device_isMobile                                                                False
# device_mobileDeviceBranding                            not available in demo dataset
# device_mobileDeviceModel                               not available in demo dataset
# device_mobileInputSelector                             not available in demo dataset
# device_mobileDeviceInfo                                not available in demo dataset
# device_mobileDeviceMarketingName                       not available in demo dataset
# device_flashVersion                                    not available in demo dataset
# device_language                                        not available in demo dataset
# device_screenColors                                    not available in demo dataset
# device_screenResolution                                not available in demo dataset
# device_deviceCategory                                                        desktop
# geoNetwork_continent                                                        Americas
# geoNetwork_subContinent                                             Northern America
# geoNetwork_country                                                     United States
# geoNetwork_region                                                         California
# geoNetwork_metro                                   San Francisco-Oakland-San Jose CA
# geoNetwork_city                                                        San Francisco
# geoNetwork_cityId                                      not available in demo dataset
# geoNetwork_networkDomain                                                   (not set)
# geoNetwork_latitude                                    not available in demo dataset
# geoNetwork_longitude                                   not available in demo dataset
# geoNetwork_networkLocation                             not available in demo dataset
# totals_bounces                                                                   NaN
# totals_hits                                                                        4
# totals_newVisits                                                                 NaN
# totals_pageviews                                                                   3
# totals_sessionQualityDim                                                           1
# totals_timeOnSite                                                                 49
# totals_totalTransactionRevenue                                                   NaN
# totals_transactionRevenue                                                        NaN
# totals_transactions                                                              NaN
# totals_visits                                                                      1
# trafficSource_adContent                                                    (not set)
# trafficSource_adwordsClickInfo_adNetworkType                                     NaN
# trafficSource_adwordsClickInfo_criteriaParameters      not available in demo dataset
# trafficSource_adwordsClickInfo_gclId                                             NaN
# trafficSource_adwordsClickInfo_isVideoAd                                         NaN
# trafficSource_adwordsClickInfo_page                                              NaN
# trafficSource_adwordsClickInfo_slot                                              NaN
# trafficSource_campaign                                                     (not set)
# trafficSource_isTrueDirect                                                      True
# trafficSource_keyword                                                      (not set)
# trafficSource_medium                                                          (none)
# trafficSource_referralPath                                                 (not set)
# trafficSource_source                                                        (direct)
# has_revenue                                                                        0
#
#                                                                                2  \
# channelGrouping                                                   Organic Search
# date                                                                    20180511
# fullVisitorId                                                3461808543879602873
# socialEngagementType                                        Not Socially Engaged
# visitId                                                               1526067157
# visitNumber                                                                    2
# visitStartTime                                                        1526067157
# rowId                                                                          2
# device_browser                                                            Chrome
# device_browserVersion                              not available in demo dataset
# device_browserSize                                 not available in demo dataset
# device_operatingSystem                                                 Chrome OS
# device_operatingSystemVersion                      not available in demo dataset
# device_isMobile                                                            False
# device_mobileDeviceBranding                        not available in demo dataset
# device_mobileDeviceModel                           not available in demo dataset
# device_mobileInputSelector                         not available in demo dataset
# device_mobileDeviceInfo                            not available in demo dataset
# device_mobileDeviceMarketingName                   not available in demo dataset
# device_flashVersion                                not available in demo dataset
# device_language                                    not available in demo dataset
# device_screenColors                                not available in demo dataset
# device_screenResolution                            not available in demo dataset
# device_deviceCategory                                                    desktop
# geoNetwork_continent                                                    Americas
# geoNetwork_subContinent                                         Northern America
# geoNetwork_country                                                 United States
# geoNetwork_region                                  not available in demo dataset
# geoNetwork_metro                                   not available in demo dataset
# geoNetwork_city                                    not available in demo dataset
# geoNetwork_cityId                                  not available in demo dataset
# geoNetwork_networkDomain                                 onlinecomputerworks.com
# geoNetwork_latitude                                not available in demo dataset
# geoNetwork_longitude                               not available in demo dataset
# geoNetwork_networkLocation                         not available in demo dataset
# totals_bounces                                                               NaN
# totals_hits                                                                    4
# totals_newVisits                                                             NaN
# totals_pageviews                                                               3
# totals_sessionQualityDim                                                       1
# totals_timeOnSite                                                             24
# totals_totalTransactionRevenue                                               NaN
# totals_transactionRevenue                                                    NaN
# totals_transactions                                                          NaN
# totals_visits                                                                  1
# trafficSource_adContent                                                (not set)
# trafficSource_adwordsClickInfo_adNetworkType                                 NaN
# trafficSource_adwordsClickInfo_criteriaParameters  not available in demo dataset
# trafficSource_adwordsClickInfo_gclId                                         NaN
# trafficSource_adwordsClickInfo_isVideoAd                                     NaN
# trafficSource_adwordsClickInfo_page                                          NaN
# trafficSource_adwordsClickInfo_slot                                          NaN
# trafficSource_campaign                                                 (not set)
# trafficSource_isTrueDirect                                                  True
# trafficSource_keyword                                             (not provided)
# trafficSource_medium                                                     organic
# trafficSource_referralPath                                             (not set)
# trafficSource_source                                                      google
# has_revenue                                                                    0
#
#                                                                                3  \
# channelGrouping                                                           Direct
# date                                                                    20180511
# fullVisitorId                                                 975129477712150630
# socialEngagementType                                        Not Socially Engaged
# visitId                                                               1526107551
# visitNumber                                                                    4
# visitStartTime                                                        1526107551
# rowId                                                                          3
# device_browser                                                            Chrome
# device_browserVersion                              not available in demo dataset
# device_browserSize                                 not available in demo dataset
# device_operatingSystem                                                       iOS
# device_operatingSystemVersion                      not available in demo dataset
# device_isMobile                                                             True
# device_mobileDeviceBranding                        not available in demo dataset
# device_mobileDeviceModel                           not available in demo dataset
# device_mobileInputSelector                         not available in demo dataset
# device_mobileDeviceInfo                            not available in demo dataset
# device_mobileDeviceMarketingName                   not available in demo dataset
# device_flashVersion                                not available in demo dataset
# device_language                                    not available in demo dataset
# device_screenColors                                not available in demo dataset
# device_screenResolution                            not available in demo dataset
# device_deviceCategory                                                     mobile
# geoNetwork_continent                                                    Americas
# geoNetwork_subContinent                                         Northern America
# geoNetwork_country                                                 United States
# geoNetwork_region                                                          Texas
# geoNetwork_metro                                                      Houston TX
# geoNetwork_city                                                          Houston
# geoNetwork_cityId                                  not available in demo dataset
# geoNetwork_networkDomain                                               (not set)
# geoNetwork_latitude                                not available in demo dataset
# geoNetwork_longitude                               not available in demo dataset
# geoNetwork_networkLocation                         not available in demo dataset
# totals_bounces                                                               NaN
# totals_hits                                                                    5
# totals_newVisits                                                             NaN
# totals_pageviews                                                               4
# totals_sessionQualityDim                                                       1
# totals_timeOnSite                                                             25
# totals_totalTransactionRevenue                                               NaN
# totals_transactionRevenue                                                    NaN
# totals_transactions                                                          NaN
# totals_visits                                                                  1
# trafficSource_adContent                                                (not set)
# trafficSource_adwordsClickInfo_adNetworkType                                 NaN
# trafficSource_adwordsClickInfo_criteriaParameters  not available in demo dataset
# trafficSource_adwordsClickInfo_gclId                                         NaN
# trafficSource_adwordsClickInfo_isVideoAd                                     NaN
# trafficSource_adwordsClickInfo_page                                          NaN
# trafficSource_adwordsClickInfo_slot                                          NaN
# trafficSource_campaign                                                 (not set)
# trafficSource_isTrueDirect                                                  True
# trafficSource_keyword                                                  (not set)
# trafficSource_medium                                                      (none)
# trafficSource_referralPath                                             (not set)
# trafficSource_source                                                    (direct)
# has_revenue                                                                    0
#
#                                                                                4
# channelGrouping                                                   Organic Search
# date                                                                    20180511
# fullVisitorId                                                8381672768065729990
# socialEngagementType                                        Not Socially Engaged
# visitId                                                               1526060254
# visitNumber                                                                    1
# visitStartTime                                                        1526060254
# rowId                                                                          4
# device_browser                                                 Internet Explorer
# device_browserVersion                              not available in demo dataset
# device_browserSize                                 not available in demo dataset
# device_operatingSystem                                                   Windows
# device_operatingSystemVersion                      not available in demo dataset
# device_isMobile                                                             True
# device_mobileDeviceBranding                        not available in demo dataset
# device_mobileDeviceModel                           not available in demo dataset
# device_mobileInputSelector                         not available in demo dataset
# device_mobileDeviceInfo                            not available in demo dataset
# device_mobileDeviceMarketingName                   not available in demo dataset
# device_flashVersion                                not available in demo dataset
# device_language                                    not available in demo dataset
# device_screenColors                                not available in demo dataset
# device_screenResolution                            not available in demo dataset
# device_deviceCategory                                                     tablet
# geoNetwork_continent                                                    Americas
# geoNetwork_subContinent                                         Northern America
# geoNetwork_country                                                 United States
# geoNetwork_region                                                     California
# geoNetwork_metro                                                  Los Angeles CA
# geoNetwork_city                                                           Irvine
# geoNetwork_cityId                                  not available in demo dataset
# geoNetwork_networkDomain                                                     com
# geoNetwork_latitude                                not available in demo dataset
# geoNetwork_longitude                               not available in demo dataset
# geoNetwork_networkLocation                         not available in demo dataset
# totals_bounces                                                               NaN
# totals_hits                                                                    5
# totals_newVisits                                                               1
# totals_pageviews                                                               4
# totals_sessionQualityDim                                                       1
# totals_timeOnSite                                                             49
# totals_totalTransactionRevenue                                               NaN
# totals_transactionRevenue                                                    NaN
# totals_transactions                                                          NaN
# totals_visits                                                                  1
# trafficSource_adContent                                                (not set)
# trafficSource_adwordsClickInfo_adNetworkType                                 NaN
# trafficSource_adwordsClickInfo_criteriaParameters  not available in demo dataset
# trafficSource_adwordsClickInfo_gclId                                         NaN
# trafficSource_adwordsClickInfo_isVideoAd                                     NaN
# trafficSource_adwordsClickInfo_page                                          NaN
# trafficSource_adwordsClickInfo_slot                                          NaN
# trafficSource_campaign                                                 (not set)
# trafficSource_isTrueDirect                                                   NaN
# trafficSource_keyword                                             (not provided)
# trafficSource_medium                                                     organic
# trafficSource_referralPath                                             (not set)
# trafficSource_source                                                      google
# has_revenue                                                                    0

# %%
df = pd.DataFrame({
        'fullVisitorId': df_test_full.fullVisitorId,
        'has_revenue_count': df_test_full.has_revenue,
})
df_revcount = df.groupby('fullVisitorId').sum()

# %%
import seaborn as sns

df_power_users = df_revcount[df_revcount.has_revenue_count >= 2]

# %%
df_power_users.head()
# Out:
#                       has_revenue_count
# fullVisitorId
# 0010364132187346780                   4
# 00135135903467220901                  2
# 0024858640770880554                   2
# 0086996858439022801                   3
# 0136175134016205768                   2

# %%
power_user_set = set(df_power_users.index)

# %%
df_test_power_users = df_test_full[df_test_full.fullVisitorId.isin(power_user_set)]

# %%
df_test_power_users_5m = df_test_power_users[
    (df_test_power_users.date >= 20180501) & (df_test_power_users.date <= 20180931)]

# %%
df_test_power_users_4m = df_test_power_users[
    (df_test_power_users.date >= 20180601) & (df_test_power_users.date <= 20180931)]

# %%
df = pd.DataFrame({
    'fullVisitorId': df_test_power_users_5m.fullVisitorId,
    'revenue': df_test_power_users_5m.totals_transactionRevenue.astype(np.float64).fillna(0.0),
}).groupby('fullVisitorId').sum() * (2. / 5.)
df.head()
# Out:
#                           revenue
# fullVisitorId
# 0010364132187346780   518160000.0
# 00135135903467220901          0.0
# 0024858640770880554   126976000.0
# 0086996858439022801    36460000.0
# 0136175134016205768   146616000.0

# %%
df = np.log1p(df)
df.head()
# Out:
#                         revenue
# fullVisitorId
# 0010364132187346780   20.065795
# 00135135903467220901   0.000000
# 0024858640770880554   18.659509
# 0086996858439022801   17.411726
# 0136175134016205768   18.803327

# %%
df_ss = pd.read_csv('sample_submission_v2.csv.zip', dtype={'fullVisitorId': np.object})

# %%
len(df_ss)
# Out:
# 296530

# %%
df_submit = df_ss.merge(df, how='left', on='fullVisitorId')
df_submit.head()
# Out:
#          fullVisitorId  PredictedLogRevenue  revenue
# 0  0000018966949534117                  0.0      NaN
# 1  0000039738481224681                  0.0      NaN
# 2  0000073585230191399                  0.0      NaN
# 3  0000087588448856385                  0.0      NaN
# 4  0000149787903119437                  0.0      NaN

# %%
df_submit[df_submit.revenue.notna()].head()
# Out:
#              fullVisitorId  PredictedLogRevenue    revenue
# 319    0010364132187346780                  0.0  20.065795
# 404   00135135903467220901                  0.0   0.000000
# 762    0024858640770880554                  0.0  18.659509
# 2530   0086996858439022801                  0.0  17.411726
# 3989   0136175134016205768                  0.0  18.803327

# %%
df_submit.PredictedLogRevenue = df_submit.revenue.fillna(0.0)
df_submit.head()
# Out:
#          fullVisitorId  PredictedLogRevenue  revenue
# 0  0000018966949534117                  0.0      NaN
# 1  0000039738481224681                  0.0      NaN
# 2  0000073585230191399                  0.0      NaN
# 3  0000087588448856385                  0.0      NaN
# 4  0000149787903119437                  0.0      NaN

# %%
df_submit = df_submit.drop(columns=['revenue'])

# %%
df_submit[df_submit.fullVisitorId.isin(power_user_set)].PredictedLogRevenue.sum()
# Out:
# 5570.549252891604

# %%
df_submit.PredictedLogRevenue.sum()
# Out:
# 5570.549252891602

# %%
df_submit[~df_submit.fullVisitorId.isin(power_user_set)].PredictedLogRevenue.sum()
# Out:
# 0.0

# %%
df_submit.to_csv('submission2_adhoc.csv', index=False)

# %%
df_test_power_users_3m = df_test_power_users[
    (df_test_power_users.date >= 20180701) & (df_test_power_users.date <= 20180931)]

# %%
df_revenue_3m = pd.DataFrame({
    'fullVisitorId': df_test_power_users_3m.fullVisitorId,
    'revenue': df_test_power_users_3m.totals_transactionRevenue.astype(np.float64).fillna(0.0),
}).groupby('fullVisitorId').sum() * (2. / 3.)
df_revenue_3m = np.log1p(df_revenue_3m)
df_revenue_3m.head()
# Out:
#                            revenue
# fullVisitorId
# 0010364132187346780   8.636000e+08
# 00135135903467220901  0.000000e+00
# 0024858640770880554   2.116267e+08
# 0086996858439022801   1.172667e+07
# 0136175134016205768   1.727067e+08

# %%
df_submit2 = df_ss.merge(df_revenue_3m, how='left', on='fullVisitorId')
df_submit2.PredictedLogRevenue = df_submit2.revenue.fillna(0.0)
df_submit2.drop(columns=['revenue'], inplace=True)
df_submit2.head()
# Out:
#          fullVisitorId  PredictedLogRevenue
# 0  0000018966949534117                  0.0
# 1  0000039738481224681                  0.0
# 2  0000073585230191399                  0.0
# 3  0000087588448856385                  0.0
# 4  0000149787903119437                  0.0

# %%
df_submit2.to_csv('submission3_adhoc.csv', index=False)

# %%
len(df_submit2)
# Out:
# 296530

# %%
len(power_user_set)
# Out:
# 318

# %%
df_revcount.groupby('fullVisitorId').sum().has_revenue_count.value_counts()
# Out:
# 0     292374
# 1       3838
# 2        254
# 3         39
# 4         16
# 5          4
# 14         1
# 10         1
# 9          1
# 8          1
# 6          1
# Name: has_revenue_count, dtype: int64
